# %% [markdown]
# # Importing and Reading Datasets
#
# The basic importing and reading the dataset includes:
#
# 1. Importing the library and the dataset
# 2. Viewing dimension and shape
# 2. Viewing the top/bottom-n results with `head(n)` and `tail(n)` functions
# 3. Viewing data with all the columns displayed

# %% [markdown]
# ## Importing the library and the dataset

# %%
import pandas as pd

# %%
data = pd.read_csv('../00_Datasets/Toyota.csv')
data
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %% [markdown]
# ## Dimensionality of the Dataset

# %%
# Viewing the dimension of the data :

data.ndim
# Out:
# 2

# %%
# Viewing the rows and columns of the data:

data.shape
# Out:
# (1436, 11)

# %%
# Viewing the total datapoints (rows x columns):

data.size
# Out:
# 15796

# %% [markdown]
# ## Viewing Portion of Dataset

# %%
# Viewing first 10 rows of data:

data.head(10)
# Out:
#    Unnamed: 0  Price   Age     KM FuelType    HP  MetColor  Automatic    CC  \
# 0           0  13500  23.0  46986   Diesel    90       1.0          0  2000
# 1           1  13750  23.0  72937   Diesel    90       1.0          0  2000
# 2           2  13950  24.0  41711   Diesel    90       NaN          0  2000
# 3           3  14950  26.0  48000   Diesel    90       0.0          0  2000
# 4           4  13750  30.0  38500   Diesel    90       0.0          0  2000
# 5           5  12950  32.0  61000   Diesel    90       0.0          0  2000
# 6           6  16900  27.0     ??   Diesel  ????       NaN          0  2000
# 7           7  18600  30.0  75889      NaN    90       1.0          0  2000
# 8           8  21500  27.0  19700   Petrol   192       0.0          0  1800
# 9           9  12950  23.0  71138   Diesel  ????       NaN          0  1900
#
#    Doors  Weight
# 0  three    1165
# 1      3    1165
# 2      3    1165
# 3      3    1165
# 4      3    1170
# 5      3    1170
# ...

# %%
# Viewing last 10 rows of data:

data.tail(10)
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 1426        1426   9950  78.0  30964   Petrol  110       NaN          1  1600
# 1427        1427   8950   NaN  29000   Petrol   86       1.0          1  1300
# 1428        1428   8450  72.0     ??   Petrol   86       NaN          0  1300
# 1429        1429   8950  78.0  24000   Petrol   86       1.0          1  1300
# 1430        1430   8450  80.0  23000   Petrol   86       0.0          0  1300
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#      Doors  Weight
# 1426     3    1080
# 1427     3    1045
# 1428     3    1015
# 1429     5    1065
# ...

# %% [markdown]
# ## Viewing all the columns and rows

# %%
# settings to view all the columns:

pd.set_option('display.max_columns', 11)
data
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
# settings to view all n-rows:

pd.set_option('display.max_rows', 1436)
data
# Out:
#       Unnamed: 0  Price   Age      KM FuelType    HP  MetColor  Automatic  \
# 0              0  13500  23.0   46986   Diesel    90       1.0          0
# 1              1  13750  23.0   72937   Diesel    90       1.0          0
# 2              2  13950  24.0   41711   Diesel    90       NaN          0
# 3              3  14950  26.0   48000   Diesel    90       0.0          0
# 4              4  13750  30.0   38500   Diesel    90       0.0          0
# 5              5  12950  32.0   61000   Diesel    90       0.0          0
# 6              6  16900  27.0      ??   Diesel  ????       NaN          0
# 7              7  18600  30.0   75889      NaN    90       1.0          0
# 8              8  21500  27.0   19700   Petrol   192       0.0          0
# 9              9  12950  23.0   71138   Diesel  ????       NaN          0
# 10            10  20950  25.0   31461   Petrol   192       0.0          0
# 11            11  19950  22.0   43610   Petrol   192       0.0          0
# ...
